# %%
import pycaret

# %%
##from pycaret.datasets import get_data
##get_data('index')

# %%
import numpy as np
import pandas as pd

# %%
from pycaret.datasets import get_data
data = get_data('house')
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
data.isna().count()
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1460
# LotArea          1460
#                  ...
# MoSold           1460
# YrSold           1460
# SaleType         1460
# SaleCondition    1460
# SalePrice        1460
# Length: 81, dtype: int64

# %%
df = pd.read_csv ('https://raw.githubusercontent.com/pycaret/datasets/main/data/common/house.csv')
## pd.set_option('display.max_columns', None)
df
##df.columns
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df2 = df
df2
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df5 = pd.read_csv ('https://raw.githubusercontent.com/pycaret/datasets/main/data/common/concrete.csv')
df5.shape
# Out:
# (1030, 9)

# %%
df2.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df4 = df2.drop(['Id', 'MSSubClass', 'MSZoning',  'Street',
       'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope',  'Condition2', 'BldgType',
       
       'RoofMatl',  'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
       'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 
      '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF'
      , 'Functional',  'FireplaceQu' 
      , 'GarageFinish',  'GarageArea', 
       'GarageCond',  'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal',  'SaleType',
       'SaleCondition',], axis=1)

# %%
df4
# Out:
#       LotFrontage  LotArea Neighborhood Condition1 HouseStyle  OverallQual  \
# 0            65.0     8450      CollgCr       Norm     2Story            7
# 1            80.0     9600      Veenker      Feedr     1Story            6
# 2            68.0    11250      CollgCr       Norm     2Story            7
# 3            60.0     9550      Crawfor       Norm     2Story            7
# 4            84.0    14260      NoRidge       Norm     2Story            8
# ...           ...      ...          ...        ...        ...          ...
# 1455         62.0     7917      Gilbert       Norm     2Story            6
# 1456         85.0    13175       NWAmes       Norm     1Story            6
# 1457         66.0     9042      Crawfor       Norm     2Story            7
# 1458         68.0     9717        NAmes       Norm     1Story            5
# 1459         75.0     9937      Edwards       Norm     1Story            5
#
# ...

# %%
df4.to_csv('./RegressionData/House1.csv', index=False)

# %%
def minmax(x):
    return pd.Series(index=['min', 'max','mean','cleanQtile'], data=[x.min(), x.max(),x.mean(),x.quantile(q=0.75) - x.quantile(q=0.25)])
df4.apply(minmax).T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\juud0\miniconda3\envs\pip310\lib\site-packages\pandas\core\nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\Users\juud0\miniconda3\envs\pip310\lib\site-packages\pandas\core\nanops.py:1634, in _ensure_numeric(x)
#    1633 try:
# -> 1634     x = complex(x)
#    1635 except ValueError as err:
#    1636     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
## df3 = df2.drop(['LotFrontage','LotArea','Neighborhood','Condition1','HouseStyle','OverallQual','OverallCond','YearBuilt','YearRemodAdd','RoofStyle','Exterior1st','TotalBsmtSF',
     ##        'Heating','HeatingQC','CentralAir','Electrical','GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr','TotRmsAbvGrd','Fireplaces',
      ##       'GarageType','GarageYrBlt','GarageCars','GarageQual','PavedDrive','PoolArea','MoSold','YrSold','SalePrice'], axis=1)

# %%
## df3 = df2.drop(['LotFrontage','LotArea','Neighborhood','Condition1','HouseStyle','OverallQual','OverallCond','YearBuilt','YearRemodAdd','RoofStyle','Exterior1st','TotalBsmtSF',
       ##      'Heating','HeatingQC','CentralAir','Electrical','GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr','TotRmsAbvGrd','Fireplaces',
         ##    'GarageType','GarageYrBlt','GarageCars','GarageQual','PavedDrive','PoolArea','MoSold','YrSold','SalePrice'], axis=1)

# %%
##df3

# %%
df2.columns = ['LotFrontage','LotArea','Neighborhood','Condition1','HouseStyle','OverallQual','OverallCond','YearBuilt','YearRemodAdd','RoofStyle','Exterior1st','TotalBsmtSF',
             'Heating','HeatingQC','CentralAir','Electrical','GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr','TotRmsAbvGrd','Fireplaces',
             'GarageType','GarageYrBlt','GarageCars','GarageQual','PavedDrive','PoolArea','MoSold','YrSold','SalePrice']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 df2.columns = ['LotFrontage','LotArea','Neighborhood','Condition1','HouseStyle','OverallQual','OverallCond','YearBuilt','YearRemodAdd','RoofStyle','Exterior1st','TotalBsmtSF',
#       2              'Heating','HeatingQC','CentralAir','Electrical','GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr','TotRmsAbvGrd','Fireplaces',
#       3              'GarageType','GarageYrBlt','GarageCars','GarageQual','PavedDrive','PoolArea','MoSold','YrSold','SalePrice']
#
# File c:\Users\juud0\miniconda3\envs\pip310\lib\site-packages\pandas\core\generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
# ...

# %%
df2.columns = ['LotFrontage','LotArea','Neighborhood']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df2.columns = ['LotFrontage','LotArea','Neighborhood']
#
# File c:\Users\juud0\miniconda3\envs\pip310\lib\site-packages\pandas\core\generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File c:\Users\juud0\miniconda3\envs\pip310\lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\juud0\miniconda3\envs\pip310\lib\site-packages\pandas\core\generic.py:823, in NDFrame._set_axis(self, axis, labels)
#     821 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     822     labels = ensure_index(labels)
# ...
