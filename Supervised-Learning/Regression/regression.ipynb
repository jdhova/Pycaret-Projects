# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv ('https://raw.githubusercontent.com/pycaret/datasets/main/data/common/concrete.csv')
df.columns
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'strength'],
#       dtype='object')

# %%
df.columns = ['cement','slag','ash','water','superplastic','coarseAgg','fineAgg','age','strength']
df
# Out:
#       cement   slag    ash  water  superplastic  coarseAgg  fineAgg  age  \
# 0      540.0    0.0    0.0  162.0           2.5     1040.0    676.0   28
# 1      540.0    0.0    0.0  162.0           2.5     1055.0    676.0   28
# 2      332.5  142.5    0.0  228.0           0.0      932.0    594.0  270
# 3      332.5  142.5    0.0  228.0           0.0      932.0    594.0  365
# 4      198.6  132.4    0.0  192.0           0.0      978.4    825.5  360
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1026   322.2    0.0  115.6  196.0          10.4      817.9    813.4   28
# 1027   148.5  139.4  108.6  192.7           6.1      892.4    780.0   28
# 1028   159.1  186.7    0.0  175.6          11.3      989.6    788.9   28
# 1029   260.9  100.5   78.3  200.6           8.6      864.5    761.5   28
#
#       strength
# 0        79.99
# 1        61.89
# 2        40.27
# 3        41.05
# 4        44.30
# ...        ...
# 1025     44.28
# 1026     31.18
# 1027     23.70
# 1028     32.77
# 1029     32.40
#
# [1030 rows x 9 columns]

# %%
##df.to_csv('../Regression/', index=False)

# %%
df.to_csv('./regressionData-Concrete.csv', index=False)

# %%
## df.to_csv('../../Supervised-Learning/data/concrete.csv', index=False)

# %%
## checking for scaling

def minmax(x):
    return pd.Series(index=['min', 'max','mean','cleanQtile'], data=[x.min(), x.max(),x.mean(),x.quantile(q=0.75) - x.quantile(q=0.25)])
df.apply(minmax).T
# Out:
#                  min     max        mean  cleanQtile
# cement        102.00   540.0  281.167864     157.625
# slag            0.00   359.4   73.895825     142.950
# ash             0.00   200.1   54.188350     118.300
# water         121.80   247.0  181.567282      27.100
# superplastic    0.00    32.2    6.204660      10.200
# coarseAgg     801.00  1145.0  972.918932      97.400
# fineAgg       594.00   992.6  773.580485      93.050
# age             1.00   365.0   45.662136      49.000
# strength        2.33    82.6   35.817961      22.425

# %%
## Remove unseen samples

data = df.sample(frac=0.99,random_state=28)
data_unseen = df.drop(data.index)

print(f'Data for model: {data.shape},\nData for unseen predictions: { data_unseen.shape}')
# Out:
# Data for model: (1020, 9),
# Data for unseen predictions: (10, 9)

# %%
from pycaret.regression import *
reg = setup(data = data, target='strength', normalize=True, session_id=42)
# Out:
# <style type="text/css">
# #T_dd78e_row8_col1, #T_dd78e_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_dd78e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd78e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_dd78e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd78e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd78e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_dd78e_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd78e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_dd78e_row1_col1" class="data row1 col1" >strength</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd78e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_dd78e_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dd78e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_dd78e_row3_col1" class="data row3 col1" >(1020, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dd78e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_dd78e_row4_col1" class="data row4 col1" >(1020, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dd78e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_dd78e_row5_col1" class="data row5 col1" >(714, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dd78e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_dd78e_row6_col1" class="data row6 col1" >(306, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dd78e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_dd78e_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dd78e_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_dd78e_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dd78e_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_dd78e_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dd78e_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_dd78e_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dd78e_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_dd78e_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dd78e_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_dd78e_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dd78e_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_dd78e_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dd78e_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_dd78e_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dd78e_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_dd78e_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_dd78e_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_dd78e_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_dd78e_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_dd78e_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_dd78e_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_dd78e_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_dd78e_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_dd78e_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_dd78e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_dd78e_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_dd78e_row20_col1" class="data row20 col1" >51df</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models(exclude=['omp','dummy'])
# Out:
# <style type="text/css">
# #T_47fcc th {
#   text-align: left;
# }
# #T_47fcc_row0_col0, #T_47fcc_row0_col6, #T_47fcc_row1_col0, #T_47fcc_row1_col1, #T_47fcc_row1_col2, #T_47fcc_row1_col3, #T_47fcc_row1_col4, #T_47fcc_row1_col5, #T_47fcc_row2_col0, #T_47fcc_row2_col1, #T_47fcc_row2_col2, #T_47fcc_row2_col3, #T_47fcc_row2_col4, #T_47fcc_row2_col5, #T_47fcc_row2_col6, #T_47fcc_row3_col0, #T_47fcc_row3_col1, #T_47fcc_row3_col2, #T_47fcc_row3_col3, #T_47fcc_row3_col4, #T_47fcc_row3_col5, #T_47fcc_row3_col6, #T_47fcc_row4_col0, #T_47fcc_row4_col1, #T_47fcc_row4_col2, #T_47fcc_row4_col3, #T_47fcc_row4_col4, #T_47fcc_row4_col5, #T_47fcc_row4_col6, #T_47fcc_row5_col0, #T_47fcc_row5_col1, #T_47fcc_row5_col2, #T_47fcc_row5_col3, #T_47fcc_row5_col4, #T_47fcc_row5_col5, #T_47fcc_row5_col6, #T_47fcc_row6_col0, #T_47fcc_row6_col1, #T_47fcc_row6_col2, #T_47fcc_row6_col3, #T_47fcc_row6_col4, #T_47fcc_row6_col5, #T_47fcc_row6_col6, #T_47fcc_row7_col0, #T_47fcc_row7_col1, #T_47fcc_row7_col2, #T_47fcc_row7_col3, #T_47fcc_row7_col4, #T_47fcc_row7_col5, #T_47fcc_row7_col6, #T_47fcc_row8_col0, #T_47fcc_row8_col1, #T_47fcc_row8_col2, #T_47fcc_row8_col3, #T_47fcc_row8_col4, #T_47fcc_row8_col5, #T_47fcc_row8_col6, #T_47fcc_row9_col0, #T_47fcc_row9_col1, #T_47fcc_row9_col2, #T_47fcc_row9_col3, #T_47fcc_row9_col4, #T_47fcc_row9_col5, #T_47fcc_row9_col6, #T_47fcc_row10_col0, #T_47fcc_row10_col1, #T_47fcc_row10_col2, #T_47fcc_row10_col3, #T_47fcc_row10_col4, #T_47fcc_row10_col5, #T_47fcc_row10_col6, #T_47fcc_row11_col0, #T_47fcc_row11_col1, #T_47fcc_row11_col2, #T_47fcc_row11_col3, #T_47fcc_row11_col4, #T_47fcc_row11_col5, #T_47fcc_row11_col6, #T_47fcc_row12_col0, #T_47fcc_row12_col1, #T_47fcc_row12_col2, #T_47fcc_row12_col3, #T_47fcc_row12_col4, #T_47fcc_row12_col5, #T_47fcc_row12_col6, #T_47fcc_row13_col0, #T_47fcc_row13_col1, #T_47fcc_row13_col2, #T_47fcc_row13_col3, #T_47fcc_row13_col4, #T_47fcc_row13_col5, #T_47fcc_row13_col6, #T_47fcc_row14_col0, #T_47fcc_row14_col1, #T_47fcc_row14_col2, #T_47fcc_row14_col3, #T_47fcc_row14_col4, #T_47fcc_row14_col5, #T_47fcc_row14_col6, #T_47fcc_row15_col0, #T_47fcc_row15_col1, #T_47fcc_row15_col2, #T_47fcc_row15_col3, #T_47fcc_row15_col4, #T_47fcc_row15_col5, #T_47fcc_row15_col6 {
#   text-align: left;
# }
# #T_47fcc_row0_col1, #T_47fcc_row0_col2, #T_47fcc_row0_col3, #T_47fcc_row0_col4, #T_47fcc_row0_col5, #T_47fcc_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_47fcc_row0_col7, #T_47fcc_row1_col7, #T_47fcc_row2_col7, #T_47fcc_row3_col7, #T_47fcc_row4_col7, #T_47fcc_row5_col7, #T_47fcc_row6_col7, #T_47fcc_row7_col7, #T_47fcc_row8_col7, #T_47fcc_row9_col7, #T_47fcc_row10_col7, #T_47fcc_row11_col7, #T_47fcc_row12_col7, #T_47fcc_row13_col7, #T_47fcc_row14_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_47fcc_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_47fcc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47fcc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_47fcc_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_47fcc_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_47fcc_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_47fcc_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_47fcc_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_47fcc_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_47fcc_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47fcc_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_47fcc_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_47fcc_row0_col1" class="data row0 col1" >3.4067</td>
#       <td id="T_47fcc_row0_col2" class="data row0 col2" >24.7720</td>
#       <td id="T_47fcc_row0_col3" class="data row0 col3" >4.9020</td>
#       <td id="T_47fcc_row0_col4" class="data row0 col4" >0.9077</td>
#       <td id="T_47fcc_row0_col5" class="data row0 col5" >0.1499</td>
#       <td id="T_47fcc_row0_col6" class="data row0 col6" >0.1149</td>
#       <td id="T_47fcc_row0_col7" class="data row0 col7" >0.0370</td>
#     </tr>
#     <tr>
#       <th id="T_47fcc_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_47fcc_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_47fcc_row1_col1" class="data row1 col1" >3.4224</td>
#       <td id="T_47fcc_row1_col2" class="data row1 col2" >29.2213</td>
#       <td id="T_47fcc_row1_col3" class="data row1 col3" >5.2592</td>
#       <td id="T_47fcc_row1_col4" class="data row1 col4" >0.8915</td>
#       <td id="T_47fcc_row1_col5" class="data row1 col5" >0.1576</td>
#       <td id="T_47fcc_row1_col6" class="data row1 col6" >0.1141</td>
#       <td id="T_47fcc_row1_col7" class="data row1 col7" >0.0640</td>
#     </tr>
#     <tr>
#       <th id="T_47fcc_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_47fcc_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_47fcc_row2_col1" class="data row2 col1" >3.9082</td>
#       <td id="T_47fcc_row2_col2" class="data row2 col2" >32.1600</td>
#       <td id="T_47fcc_row2_col3" class="data row2 col3" >5.5863</td>
#       <td id="T_47fcc_row2_col4" class="data row2 col4" >0.8804</td>
#       <td id="T_47fcc_row2_col5" class="data row2 col5" >0.1736</td>
#       <td id="T_47fcc_row2_col6" class="data row2 col6" >0.1339</td>
#       <td id="T_47fcc_row2_col7" class="data row2 col7" >0.0620</td>
#     </tr>
#     <tr>
#       <th id="T_47fcc_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_47fcc_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_47fcc_row3_col1" class="data row3 col1" >4.2245</td>
#       <td id="T_47fcc_row3_col2" class="data row3 col2" >33.1190</td>
#       <td id="T_47fcc_row3_col3" class="data row3 col3" >5.6632</td>
#       <td id="T_47fcc_row3_col4" class="data row3 col4" >0.8751</td>
#       <td id="T_47fcc_row3_col5" class="data row3 col5" >0.1762</td>
#       <td id="T_47fcc_row3_col6" class="data row3 col6" >0.1446</td>
#       <td id="T_47fcc_row3_col7" class="data row3 col7" >0.0420</td>
#     </tr>
#     <tr>
#       <th id="T_47fcc_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_47fcc_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_47fcc_row4_col1" class="data row4 col1" >4.7547</td>
#       <td id="T_47fcc_row4_col2" class="data row4 col2" >55.5483</td>
#       <td id="T_47fcc_row4_col3" class="data row4 col3" >7.3864</td>
#       <td id="T_47fcc_row4_col4" class="data row4 col4" >0.7939</td>
#       <td id="T_47fcc_row4_col5" class="data row4 col5" >0.2199</td>
#       <td id="T_47fcc_row4_col6" class="data row4 col6" >0.1603</td>
#       <td id="T_47fcc_row4_col7" class="data row4 col7" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_47fcc_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_47fcc_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_47fcc_row5_col1" class="data row5 col1" >6.4129</td>
#       <td id="T_47fcc_row5_col2" class="data row5 col2" >62.3452</td>
#       <td id="T_47fcc_row5_col3" class="data row5 col3" >7.8640</td>
#       <td id="T_47fcc_row5_col4" class="data row5 col4" >0.7695</td>
#       <td id="T_47fcc_row5_col5" class="data row5 col5" >0.2798</td>
#       <td id="T_47fcc_row5_col6" class="data row5 col6" >0.2579</td>
#       <td id="T_47fcc_row5_col7" class="data row5 col7" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_47fcc_level0_row6" class="row_heading level0 row6" >knn</th>
#       <td id="T_47fcc_row6_col0" class="data row6 col0" >K Neighbors Regressor</td>
#       <td id="T_47fcc_row6_col1" class="data row6 col1" >7.2635</td>
#       <td id="T_47fcc_row6_col2" class="data row6 col2" >90.5846</td>
#       <td id="T_47fcc_row6_col3" class="data row6 col3" >9.3
# LGBMRegressor(random_state=42)

# %%
# model is run on the train dataset
model = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_cc4f0_row10_col0, #T_cc4f0_row10_col1, #T_cc4f0_row10_col2, #T_cc4f0_row10_col3, #T_cc4f0_row10_col4, #T_cc4f0_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_cc4f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc4f0_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_cc4f0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_cc4f0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_cc4f0_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_cc4f0_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_cc4f0_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc4f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc4f0_row0_col0" class="data row0 col0" >3.0693</td>
#       <td id="T_cc4f0_row0_col1" class="data row0 col1" >19.7519</td>
#       <td id="T_cc4f0_row0_col2" class="data row0 col2" >4.4443</td>
#       <td id="T_cc4f0_row0_col3" class="data row0 col3" >0.9269</td>
#       <td id="T_cc4f0_row0_col4" class="data row0 col4" >0.1145</td>
#       <td id="T_cc4f0_row0_col5" class="data row0 col5" >0.0855</td>
#     </tr>
#     <tr>
#       <th id="T_cc4f0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cc4f0_row1_col0" class="data row1 col0" >2.5142</td>
#       <td id="T_cc4f0_row1_col1" class="data row1 col1" >14.0463</td>
#       <td id="T_cc4f0_row1_col2" class="data row1 col2" >3.7478</td>
#       <td id="T_cc4f0_row1_col3" class="data row1 col3" >0.9542</td>
#       <td id="T_cc4f0_row1_col4" class="data row1 col4" >0.1049</td>
#       <td id="T_cc4f0_row1_col5" class="data row1 col5" >0.0764</td>
#     </tr>
#     <tr>
#       <th id="T_cc4f0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cc4f0_row2_col0" class="data row2 col0" >3.1267</td>
#       <td id="T_cc4f0_row2_col1" class="data row2 col1" >16.7283</td>
#       <td id="T_cc4f0_row2_col2" class="data row2 col2" >4.0900</td>
#       <td id="T_cc4f0_row2_col3" class="data row2 col3" >0.9300</td>
#       <td id="T_cc4f0_row2_col4" class="data row2 col4" >0.1486</td>
#       <td id="T_cc4f0_row2_col5" class="data row2 col5" >0.1140</td>
#     </tr>
#     <tr>
#       <th id="T_cc4f0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cc4f0_row3_col0" class="data row3 col0" >4.6627</td>
#       <td id="T_cc4f0_row3_col1" class="data row3 col1" >42.0308</td>
#       <td id="T_cc4f0_row3_col2" class="data row3 col2" >6.4831</td>
#       <td id="T_cc4f0_row3_col3" class="data row3 col3" >0.8591</td>
#       <td id="T_cc4f0_row3_col4" class="data row3 col4" >0.1631</td>
#       <td id="T_cc4f0_row3_col5" class="data row3 col5" >0.1371</td>
#     </tr>
#     <tr>
#       <th id="T_cc4f0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cc4f0_row4_col0" class="data row4 col0" >2.9243</td>
#       <td id="T_cc4f0_row4_col1" class="data row4 col1" >17.2832</td>
#       <td id="T_cc4f0_row4_col2" class="data row4 col2" >4.1573</td>
#       <td id="T_cc4f0_row4_col3" class="data row4 col3" >0.9430</td>
#       <td id="T_cc4f0_row4_col4" class="data row4 col4" >0.1334</td>
#       <td id="T_cc4f0_row4_col5" class="data row4 col5" >0.0970</td>
#     </tr>
#     <tr>
#       <th id="T_cc4f0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cc4f0_row5_col0" class="data row5 col0" >3.1628</td>
#       <td id="T_cc4f0_row5_col1" class="data row5 col1" >19.2498</td>
#       <td id="T_cc4f0_row5_col2" class="data row5 col2" >4.3875</td>
#       <td id="T_cc4f0_row5_col3" class="data row5 col3" >0.9142</td>
#       <td id="T_cc4f0_row5_col4" class="data row5 col4" >0.1521</td>
#       <td id="T_cc4f0_row5_col5" class="data row5 col5" >0.1129</td>
#     </tr>
#     <tr>
#       <th id="T_cc4f0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cc4f0_row6_col0" class="data row6 col0" >3.1475</td>
#       <td id="T_cc4f0_row6_col1" class="data row6 col1" >26.0820</td>
#       <td id="T_cc4f0_row6_col2" class="data row6 col2" >5.1071</td>
#       <td id="T_cc4f0_row6_col3" class="data row6 col3" >0.9132</td>
#       <td id="T_cc4f0_row6_col4" class="data row6 col4" >0.1843</td>
#       <td id="T_cc4f0_row6_col5" class="data row6 col5" >0.1280</td>
#     </tr>
#     <tr>
#       <th id="T_cc4f0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cc4f0_row7_col0" class="data row7 col0" >4.2526</td>
#       <td id="T_cc4f0_row7_col1" class="data row7 col1" >36.5330</td>
#       <td id="T_cc4f0_row7_col2" class="data row7 col2" >6.0443</td>
#       <td id="T_cc4f0_row7_col3" class="data row7 col3" >0.8578</td>
#       <td id="T_cc4f0_row7_col4" class="data row7 col4" >0.1549</td>
#       <td id="T_cc4f0_row7_col5" class="data row7 col5" >0.1223</td>
#     </tr>
#     <tr>
#       <th id="T_cc4f0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cc4f0_row8_col0" class="data row8 col0" >3.3503</td>
#       <td id="T_cc4f0_row8_col1" class="data row8 col1" >24.1388</td>
#       <td id="T_cc4f0_row8_col2" class="data row8 col2" >4.9131</td>
#       <td id="T_cc4f0_row8_col3" class="data row8 col3" >0.9212</td>
#       <td id="T_cc4f0_row8_col4" class="data row8 col4" >0.1648</td>
#       <td id="T_cc4f0_row8_col5" class="data row8 col5" >0.1308</td>
#     </tr>
#     <tr>
#       <th id="T_cc4f0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cc4f0_row9_col0" class="data row9 col0" >3.8563</td>
#       <td id="T_cc4f0_row9_col1" class="data row9 col1" >31.8757</td>
#       <td id="T_cc4f0_row9_col2" class="data row9 col2" >5.6459</td>
#       <td id="T_cc4f0_row9_col3" class="data row9 col3" >0.8576</td>
#       <td id="T_cc4f0_row9_col4" class="data row9 col4" >0.1788</td>
#       <td id="T_cc4f0_row9_col5" class="data row9 col5" >0.1450</td>
#     </tr>
#     <tr>
#       <th id="T_cc4f0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_cc4f0_row10_col0" class="data row10 col0" >3.4067</td>
#       <td id="T_cc4f0_row10_col1" class="data row10 col1" >24.7720</td>
#       <td id="T_cc4f0_row10_col2" class="data row10 col2" >4.9020</td>
#       <td id="T_cc4f0_row10_col3" class="data row10 col3" >0.9077</td>
#       <td id="T_cc4f0_row10_col4" class="data row10 col4" >0.1499</td>
#       <td id="T_cc4f0_row10_col5" class="data row10 col5" >0.1149</td>
#     </tr>
#     <tr>
#       <th id="T_cc4f0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_cc4f0_row11_col0" class="data row11 col0" >0.6202</td>
#       <td id="T_cc4f0_row11_col1" class="data row11 col1" >8.8334</td>
#       <td id="T_cc4f0_row11_col2" class="data row11 col2" >0.8614</td>
#       <td id="T_cc4f0_row11_col3" class="data row11 col3" >0.0345</td>
#       <td id="T_cc4f0_row11_col4" class="data row11 col4" >0.0245</td>
#       <td id="T_cc4f0_row11_col5" class="data row11 col5" >0.0213</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Training model on test data set
predict_model(model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_47c84">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47c84_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_47c84_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_47c84_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_47c84_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_47c84_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_47c84_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_47c84_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47c84_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47c84_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_47c84_row0_col1" class="data row0 col1" >3.1752</td>
#       <td id="T_47c84_row0_col2" class="data row0 col2" >20.2916</td>
#       <td id="T_47c84_row0_col3" class="data row0 col3" >4.5046</td>
#       <td id="T_47c84_row0_col4" class="data row0 col4" >0.9277</td>
#       <td id="T_47c84_row0_col5" class="data row0 col5" >0.1574</td>
#       <td id="T_47c84_row0_col6" class="data row0 col6" >0.1183</td>
#     </tr>
#   </tbody>
# </table>
#           cement        slag         ash       water  superplastic  \
# 714   254.000000    0.000000    0.000000  198.000000           0.0
# 715   230.000000    0.000000  118.300003  195.500000           4.6
# 716   213.800003   98.099998   24.500000  181.699997           6.7
# 717   446.000000   24.000000   79.000000  162.000000          11.6
# 718   213.500000    0.000000  174.199997  154.600006          11.7
# ...          ...         ...         ...         ...           ...
# 1015  173.500000   50.099998  173.500000  164.800003           6.5
# 1016  149.000000  236.000000    0.000000  176.000000          13.0
# 1017  237.500000  237.500000    0.000000  228.000000           0.0
# 1018  475.000000    0.000000    0.000000  228.000000           0.0
# 1019  246.800003    0.000000  125.099998  143.300003          12.0
#
#         coarseAgg     fineAgg  age   strength  prediction_label
# 714    968.000000  863.000000   90  26.940001         25.039384
# 715   1029.400024  758.599976  100  35.340000         33.918469
# 716   1066.000000  785.500000  100  49.970001         47.179640
# 717    967.000000  712.000000    7  39.299999         43.824018
# 718   1052.300049  775.500000    3  17.370001         22.764129
# ...           ...         ...  ...        ...               ...
# 1015  1006.200012  793.500000   28  38.200001         48.739442
# 1016   847.000000  893.000000   28  32.959999         31.032593
# 1017   932.000000  594.000000   90  33.119999         46.150469
# 1018   932.000000  594.000000  365  41.930000         44.842143
# 1019  1086.800049  800.900024   28  52.500000         46.385877
#
# [306 rows x 10 columns]

# %%
# Tune model goes agaist train and test 
tuned_model = tune_model(model)
# Out:
# <style type="text/css">
# #T_a6093_row10_col0, #T_a6093_row10_col1, #T_a6093_row10_col2, #T_a6093_row10_col3, #T_a6093_row10_col4, #T_a6093_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a6093">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6093_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a6093_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a6093_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a6093_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a6093_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a6093_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6093_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6093_row0_col0" class="data row0 col0" >2.9476</td>
#       <td id="T_a6093_row0_col1" class="data row0 col1" >18.0401</td>
#       <td id="T_a6093_row0_col2" class="data row0 col2" >4.2474</td>
#       <td id="T_a6093_row0_col3" class="data row0 col3" >0.9333</td>
#       <td id="T_a6093_row0_col4" class="data row0 col4" >0.1149</td>
#       <td id="T_a6093_row0_col5" class="data row0 col5" >0.0857</td>
#     </tr>
#     <tr>
#       <th id="T_a6093_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6093_row1_col0" class="data row1 col0" >2.7105</td>
#       <td id="T_a6093_row1_col1" class="data row1 col1" >14.5987</td>
#       <td id="T_a6093_row1_col2" class="data row1 col2" >3.8208</td>
#       <td id="T_a6093_row1_col3" class="data row1 col3" >0.9524</td>
#       <td id="T_a6093_row1_col4" class="data row1 col4" >0.1176</td>
#       <td id="T_a6093_row1_col5" class="data row1 col5" >0.0854</td>
#     </tr>
#     <tr>
#       <th id="T_a6093_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6093_row2_col0" class="data row2 col0" >2.5701</td>
#       <td id="T_a6093_row2_col1" class="data row2 col1" >13.5404</td>
#       <td id="T_a6093_row2_col2" class="data row2 col2" >3.6797</td>
#       <td id="T_a6093_row2_col3" class="data row2 col3" >0.9433</td>
#       <td id="T_a6093_row2_col4" class="data row2 col4" >0.1268</td>
#       <td id="T_a6093_row2_col5" class="data row2 col5" >0.0952</td>
#     </tr>
#     <tr>
#       <th id="T_a6093_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6093_row3_col0" class="data row3 col0" >4.8620</td>
#       <td id="T_a6093_row3_col1" class="data row3 col1" >49.3233</td>
#       <td id="T_a6093_row3_col2" class="data row3 col2" >7.0231</td>
#       <td id="T_a6093_row3_col3" class="data row3 col3" >0.8347</td>
#       <td id="T_a6093_row3_col4" class="data row3 col4" >0.1793</td>
#       <td id="T_a6093_row3_col5" class="data row3 col5" >0.1433</td>
#     </tr>
#     <tr>
#       <th id="T_a6093_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6093_row4_col0" class="data row4 col0" >2.3385</td>
#       <td id="T_a6093_row4_col1" class="data row4 col1" >10.5459</td>
#       <td id="T_a6093_row4_col2" class="data row4 col2" >3.2474</td>
#       <td id="T_a6093_row4_col3" class="data row4 col3" >0.9652</td>
#       <td id="T_a6093_row4_col4" class="data row4 col4" >0.1230</td>
#       <td id="T_a6093_row4_col5" class="data row4 col5" >0.0888</td>
#     </tr>
#     <tr>
#       <th id="T_a6093_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a6093_row5_col0" class="data row5 col0" >3.0146</td>
#       <td id="T_a6093_row5_col1" class="data row5 col1" >18.0419</td>
#       <td id="T_a6093_row5_col2" class="data row5 col2" >4.2476</td>
#       <td id="T_a6093_row5_col3" class="data row5 col3" >0.9196</td>
#       <td id="T_a6093_row5_col4" class="data row5 col4" >0.1406</td>
#       <td id="T_a6093_row5_col5" class="data row5 col5" >0.1059</td>
#     </tr>
#     <tr>
#       <th id="T_a6093_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a6093_row6_col0" class="data row6 col0" >2.7017</td>
#       <td id="T_a6093_row6_col1" class="data row6 col1" >23.8066</td>
#       <td id="T_a6093_row6_col2" class="data row6 col2" >4.8792</td>
#       <td id="T_a6093_row6_col3" class="data row6 col3" >0.9208</td>
#       <td id="T_a6093_row6_col4" class="data row6 col4" >0.1795</td>
#       <td id="T_a6093_row6_col5" class="data row6 col5" >0.1174</td>
#     </tr>
#     <tr>
#       <th id="T_a6093_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a6093_row7_col0" class="data row7 col0" >4.4088</td>
#       <td id="T_a6093_row7_col1" class="data row7 col1" >43.0870</td>
#       <td id="T_a6093_row7_col2" class="data row7 col2" >6.5641</td>
#       <td id="T_a6093_row7_col3" class="data row7 col3" >0.8323</td>
#       <td id="T_a6093_row7_col4" class="data row7 col4" >0.1814</td>
#       <td id="T_a6093_row7_col5" class="data row7 col5" >0.1324</td>
#     </tr>
#     <tr>
#       <th id="T_a6093_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a6093_row8_col0" class="data row8 col0" >3.2046</td>
#       <td id="T_a6093_row8_col1" class="data row8 col1" >18.2958</td>
#       <td id="T_a6093_row8_col2" class="data row8 col2" >4.2774</td>
#       <td id="T_a6093_row8_col3" class="data row8 col3" >0.9402</td>
#       <td id="T_a6093_row8_col4" class="data row8 col4" >0.1517</td>
#       <td id="T_a6093_row8_col5" class="data row8 col5" >0.1272</td>
#     </tr>
#     <tr>
#       <th id="T_a6093_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a6093_row9_col0" class="data row9 col0" >3.5198</td>
#       <td id="T_a6093_row9_col1" class="data row9 col1" >29.0765</td>
#       <td id="T_a6093_row9_col2" class="data row9 col2" >5.3923</td>
#       <td id="T_a6093_row9_col3" class="data row9 col3" >0.8701</td>
#       <td id="T_a6093_row9_col4" class="data row9 col4" >0.1669</td>
#       <td id="T_a6093_row9_col5" class="data row9 col5" >0.1306</td>
#     </tr>
#     <tr>
#       <th id="T_a6093_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a6093_row10_col0" class="data row10 col0" >3.2278</td>
#       <td id="T_a6093_row10_col1" class="data row10 col1" >23.8356</td>
#       <td id="T_a6093_row10_col2" class="data row10 col2" >4.7379</td>
#       <td id="T_a6093_row10_col3" class="data row10 col3" >0.9112</td>
#       <td id="T_a6093_row10_col4" class="data row10 col4" >0.1482</td>
#       <td id="T_a6093_row10_col5" class="data row10 col5" >0.1112</td>
#     </tr>
#     <tr>
#       <th id="T_a6093_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_a6093_row11_col0" class="data row11 col0" >0.7774</td>
#       <td id="T_a6093_row11_col1" class="data row11 col1" >12.3024</td>
#       <td id="T_a6093_row11_col2" class="data row11 col2" >1.1781</td>
#       <td id="T_a6093_row11_col3" class="data row11 col3" >0.0457</td>
#       <td id="T_a6093_row11_col4" class="data row11 col4" >0.0257</td>
#       <td id="T_a6093_row11_col5" class="data row11 col5" >0.0206</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(tuned_model)
# Out:
# LGBMRegressor(bagging_fraction=0.8, bagging_freq=3, feature_fraction=0.8,
#               learning_rate=0.2, min_child_samples=6, min_split_gain=0.6,
#               num_leaves=30, random_state=42, reg_alpha=0.001, reg_lambda=5)

# %%
final_model = finalize_model(tuned_model)
final_model
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\juud0\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['cement', 'slag', 'ash', 'water',
#                                              'superplastic', 'coarseAgg',
#                                              'fineAgg', 'age'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('normalize', TransformerWrapper(transformer=StandardScaler())),
#                 ('actual_estimator',
#                  LGBMRegressor(bagging_fraction=0.8, bagging_freq=3,
#                                feature_fraction=0.8, learning_rate=0.2,
#                                min_child_samples=6, min_split_gain=0.6,
#                                num_leaves=30, random_state=42, reg_alpha=0.001,
#                                reg_lambda=5))])

# %%
save_model(final_model, './models/concrete_ltgm')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 save_model(final_model, './models/concrete_ltgm')
#
# File c:\Users\juud0\miniconda3\envs\pip310\lib\site-packages\pycaret\utils\generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File c:\Users\juud0\miniconda3\envs\pip310\lib\site-packages\pycaret\regression\functional.py:2130, in save_model(model, model_name, model_only, verbose, **kwargs)
#    2085 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    2086 def save_model(
#    2087     model, model_name: str, model_only: bool = False, verbose: bool = True, **kwargs
#    2088 ):
#    2090     """
#    2091     This function saves the transformation pipeline and trained model object
#    2092     into the current working directory as a pickle file for later use.
#    (...)
#    2127
#    2128     """
# -> 2130     return _CURRENT_EXPERIMENT.save_model(
#    2131         model=model,
#    2132         model_name=model_name,
#    2133         model_only=model_only,
#    2134         verbose=verbose,
#    2135         **kwargs,
#    2136     )
#
# File c:\Users\juud0\miniconda3\envs\pip310\lib\site-packages\pycaret\regression\oop.py:2425, in RegressionExperiment.save_model(self, model, model_name, model_only, verbose, **kwargs)
#    2376 def save_model(
#    2377     self,
#    2378     model,
#    (...)
#    2382     **kwargs,
#    2383 ):
#    2385     """
#    2386     This function saves the transformation pipeline and trained model object
#    2387     into the current working directory as a pickle file for later use.
#    (...)
#    2422
#    2423     """
# -> 2425     return super().save_model(
#    2426         model=model,
#    2427         model_name=model_name,
#    2428         model_only=model_only,
#    2429         verbose=verbose,
#    2430         **kwargs,
#    2431     )
#
# File c:\Users\juud0\miniconda3\envs\pip310\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:2406, in _TabularExperiment.save_model(self, model, model_name, model_only, verbose, **kwargs)
#    2403 else:
#    2404     pipeline_to_use = self.pipeline
# -> 2406 model_, model_filename = pycaret.internal.persistence.save_model(
#    2407     model=model,
#    2408     model_name=model_name,
#    2409     prep_pipe_=None if model_only else pipeline_to_use,
#    2410     verbose=verbose,
#    2411     use_case=self._ml_usecase,
#    2412     **kwargs,
#    2413 )
#    2414 if self.logging_param:
#    2415     [
#    2416         logger.log_artifact(file=model_filename, type="model")
#    2417         for logger in self.logging_param.loggers
#    2418         if hasattr(logger, "remote")
#    2419     ]
#
# File c:\Users\juud0\miniconda3\envs\pip310\lib\site-packages\pycaret\internal\persistence.py:322, in save_model(model, model_name, prep_pipe_, verbose, use_case, **kwargs)
#     319         model_.steps.append(("trained_model", model))
#     321 model_name = f"{model_name}.pkl"
# --> 322 joblib.dump(model_, model_name, **kwargs)
#     323 if verbose:
#     324     print("Transformation Pipeline and Model Successfully Saved")
#
# File c:\Users\juud0\miniconda3\envs\pip310\lib\site-packages\joblib\numpy_pickle.py:552, in dump(value, filename, compress, protocol, cache_size)
#     550         NumpyPickler(f, protocol=protocol).dump(value)
#     551 elif is_filename:
# --> 552     with open(filename, 'wb') as f:
#     553         NumpyPickler(f, protocol=protocol).dump(value)
#     554 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: './models/concrete_ltgm.pkl'

# %%
model_test = load_model('concrete_ltgm')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
data = [[332.5,	142.5,	0.0,	228.0,	0.0,	932.0,	594.0,	365]]
#41.05

# %%
cols = model_test.feature_names_in_[:-1]
data_df = pd.DataFrame(data, columns=cols)
prediction = model_test.predict(data_df)[0]
prediction
# Out:
# 41.35282973394896

# %%
batch = data_unseen.iloc[:,:-1]
batch
predictions = model_test.predict(batch)
predictions
# Out:
# array([29.16396672, 68.27886247, 77.07838182, 30.60932282, 31.19140918,
#        54.39744264, 29.82951451, 46.99453254, 16.57758829, 31.93897401])

# %%
data_unseen['y-hat'] =np.round(predictions,2)
data_unseen['pct_err'] = (abs(data_unseen['strength'] - data_unseen['y-hat'])) / data_unseen['strength']
data_unseen
# Out:
#      cement   slag    ash  water  superplastic  coarseAgg  fineAgg  age  \
# 87    286.3  200.9    0.0  144.7          11.2     1004.6    803.7    3
# 140   313.3  262.2    0.0  175.5           8.6     1046.9    611.8   56
# 152   362.6  189.0    0.0  164.9          11.6      944.7    755.8   56
# 192   233.8    0.0   94.6  197.9           4.6      947.0    852.2   56
# 453   190.3    0.0  125.2  166.6           9.9     1079.0    798.9   56
# 472   446.0   24.0   79.0  162.0          11.6      967.0    712.0   28
# 476   446.0   24.0   79.0  162.0          11.6      967.0    712.0    3
# 498   355.0   19.0   97.0  145.0          12.3      967.0    871.0   28
# 606   236.0    0.0    0.0  194.0           0.0      968.0    885.0   14
# 939   145.9  230.5    0.0  202.5           3.4      827.0    871.8   28
#
#      strength  y-hat   pct_err
# 87      24.40  29.16  0.195082
# 140     64.90  68.28  0.052080
# 152     77.30  77.08  0.002846
# 192     27.66  30.61  0.106652
# 453     31.72  31.19  0.016709
# 472     44.42  54.40  0.224674
# 476     25.02  29.83  0.192246
# 498     55.45  46.99  0.152570
# 606     12.84  16.58  0.291277
# 939     32.72  31.94  0.023839

# %%
#y is the target and y-hat is the predictions of y on unsendata

# %%
evaluate_model(model_test)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
